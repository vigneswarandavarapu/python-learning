# %% [markdown]
# <a href="https://colab.research.google.com/github/vigneswarandavarapu/python-learning/blob/main/conditional_statements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#If statement#

a=10
if a==10:
  print("yes")
# Out:
# yes

# %%
#it should be in same indentation#
a=12

if a==12:
  print("one")
  print("two")
  print("10")
# Out:
# one
# two
# 10

# %%
#less than and greater than#
a=85;

if a>40:
  print('Pass')
else:
  print('fail')

b=30

if b>40:
  print('Pass')
else:
  print('fail')
# Out:
# Pass
# fail

# %%
#else if ladder#
a=10

if(a==0):
  print('a is equal to 0')
elif a<0:
  print("a is negative")
else:
  print("a is positive")
# Out:
# a is positive

# %%
marks=75

print(marks==75)

if(marks>=90):
  print("Grade A")
elif(marks>=80):
  print("Grade B")
elif(marks>=70):
  print("Grade C")
elif(marks>=60):
  print("Grade D")
# Out:
# True
# Grade C
