# %% [markdown]
# <a href="https://colab.research.google.com/github/vigneswarandavarapu/python-learning/blob/main/variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=20.9999
y=int(x)
print(type(x))
print(type(y))
print(x)
print(y)
# Out:
# <class 'float'>
# <class 'int'>
# 20.9999
# 20

# %%
x="20"
y=int(x)
print(type(x))
print(type(y))
print(x)
print(y)
# Out:
# <class 'str'>
# <class 'int'>
# 20
# 20

# %%
#Implict Type conversion: Automatically connverts type#
x=2.5
y=10
z=x+y
print(type(x))
print(type(y))
print(type(z))
print(z)
# Out:
# <class 'float'>
# <class 'int'>
# <class 'float'>
# 12.5

# %%
#problem: Calculate age from Birth. two different types#

birthYear="1994"
currentYear=2026

#need to convert birth year into INT#
birthYear=int(birthYear)
age=currentYear-birthYear
print(age)

futureYear=2030

print(f'X is Y years old and will be {futureYear-int(birthYear)} in {futureYear}')
#
# Out:
# 32
# X is Y years old and will be 36 in 2030
