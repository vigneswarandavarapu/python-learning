# %% [markdown]
# <a href="https://colab.research.google.com/github/vigneswarandavarapu/python-learning/blob/main/fiiles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
file =open('.english.txt','w')
file.write('hello world')
file.close()
file =open('.english.txt','r')
print(file.read())
# Out:
# hello world

# %%
file =open('.english.txt','w')
file.write('hello world')
file.close()

# %%
file =open('.english.txt','w')
file.write('hello world')
file.write('hello world 1')
file.write('hello world 2')
file.write('hello world 3')
file.write('hello world 4')
file.write('hello world 5')
file.write('hello world 6')
file.close()
file =open('.english.txt','r')
print(file.readlines())
# Out:
# ['hello worldhello world 1hello world 2hello world 3hello world 4hello world 5hello world 6']

# %%
file =open('.english.txt','w')
file.write('hello world')
file.write('hello world 1')
file.write('hello world 2')
file.write('hello world 3')
file.write('hello world 4')
file.write('hello world 5')
file.write('hello world 6')
file.close()
file =open('.english.txt','r')
print(file.readline())
# Out:
# hello worldhello world 1hello world 2hello world 3hello world 4hello world 5hello world 6

# %%
file =open('.english.txt','w')
file.write('hello world')
file.write('hello world 1')
file.write('\n')
file.write('hello world 2')
file.write('\n')
file.write('hello world 3')
file.write('\n')
file.write('hello world 4')
file.write('\n')
file.write('hello world 5')
file.write('\n')
file.write('hello world 6')
file.close()
file =open('.english.txt','r')
print(file.readline())
print(file.readline())
# Out:
# hello worldhello world 1
#
# hello world 2

# %%
file =open('.english.txt','w')
file.write('hello world')
file.write('hello world 1')
file.write('\n')
file.write('hello world 2')
file.write('\n')
file.write('hello world 3')
file.write('\n')
file.write('hello world 4')
file.write('\n')
file.write('hello world 5')
file.write('\n')
file.write('hello world 6')
file.close()
file =open('.english.txt','r')
print(file.readlines())
# Out:
# ['hello worldhello world 1\n', 'hello world 2\n', 'hello world 3\n', 'hello world 4\n', 'hello world 5\n', 'hello world 6']

# %%
file =open('.english.txt','w')
file.write('hello world')
file.write('hello world 1')
file.write('\n')
file.write('hello world 2')
file.write('\n')
file.write('hello world 3')
file.write('\n')
file.write('hello world 4')
file.write('\n')
file.write('hello world 5')
file.write('\n')
file.write('hello world 6')
file.close()
file =open('.english.txt','r')
for line in file:
  print(line.strip())
# Out:
# hello worldhello world 1
# hello world 2
# hello world 3
# hello world 4
# hello world 5
# hello world 6

# %%
output=open('./output.txt','w')
for i in range(0,10000000):
  output.write(str(i*i*i));
else:
  print('File updated');
# Out:
# File updated

# %%
file =open('.english.txt','a')
file.write('Test append');
file.close()
