# %% [markdown]
# <a href="https://colab.research.google.com/github/vigneswarandavarapu/python-learning/blob/main/operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s=20
p=10
s+p
# Out:
# 30

# %%
s=20
p=10
s-p
# Out:
# 10

# %%
s=20
p=10
s*p
# Out:
# 200

# %%
s=20
p=10
s/p
# Out:
# 2.0

# %%
s=20
p=10
s//p
# Out:
# 2

# %%
s=20
p=10
s%p
# Out:
# 0

# %%
s=20
p=10
s**p
# Out:
# 10240000000000

# %% [markdown]
# Operator Precedence
#
# PEMDAS
#
# P=paranthasis ()
# E= Exponent **
# M= Multiplication
# D=Divisios, // Floor, % Modulus
# A= Addition
# S=SUbstraction

# %%
print(2+3*4)
# Out:
# 14

# %%
print(100-20/5*2)
# Out:
# 92.0

# %% [markdown]
# Logical Opetrator
#
# and
#
# or
#
# not
